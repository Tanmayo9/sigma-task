# %%
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %%
companies=pd.read_csv('/Users/tanmay/Downloads/Forbes Global 2000 (Year 2022).csv')

# %%
companies.shape
# Out:
# (1999, 8)

# %%
companies.head()
# Out:
#   Rank_nr                                   Company                Industry  \
# 0       1                        Berkshire Hathaway  Diversified Financials
# 1       2                                      ICBC                 Banking
# 2       3  Saudi Arabian Oil Company (Saudi Aramco)    Oil & Gas Operations
# 3       4                            JPMorgan Chase  Diversified Financials
# 4       5                   China Construction Bank                 Banking
#
#          Country   Sales   Profits   Assets  Market_Value
# 0  United States  276094   89795.0   958784        741476
# 1          China  208127   54028.3  5518508        214425
# 2   Saudi Arabia  400376  105363.0   576041       2292077
# 3  United States  124542   42115.0  3954687        374446
# 4          China  202069   46887.3  4746951        181325

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank_nr       2000 non-null   object
#  1   Company       2000 non-null   object
#  2   Industry      2000 non-null   object
#  3   Country       2000 non-null   object
#  4   Sales         2000 non-null   int64
#  5   Profits       2000 non-null   float64
#  6   Assets        2000 non-null   int64
#  7   Market_Value  2000 non-null   int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 125.1+ KB

# %%
companies.describe()
# Out:
#                Sales        Profits        Assets  Market_Value
# count    2000.000000    2000.000000  2.000000e+03  2.000000e+03
# mean    23886.202000    2500.655400  1.171142e+05  3.823843e+04
# std     40942.544294    6159.244654  3.637458e+05  1.172073e+05
# min         0.000000  -12052.300000  1.660000e+02  1.440000e+02
# 25%      5604.000000     589.850000  1.479075e+04  7.325750e+03
# 50%     12167.500000    1054.750000  3.200700e+04  1.662550e+04
# 75%     23742.500000    2266.825000  7.787025e+04  3.471200e+04
# max    572754.000000  105363.000000  5.518508e+06  2.640316e+06

# %%
asia = companies[companies['Country'].isin(['Russia','India','China','Japan','Hongkong','Indonesia','Kazakhstan','Malaysia','Taiwan','Singapore','South Korea','Thailand','Turkey','Vietnam','United Arab Emirates','Saudi Arabia','Qatar','Kuwait','Israel','Phillipines'])]
asia
# Out:
#      Rank_nr                                    Company  \
# 1          2                                       ICBC
# 2          3   Saudi Arabian Oil Company (Saudi Aramco)
# 4          5                    China Construction Bank
# 7          8                 Agricultural Bank of China
# 9         10                               Toyota Motor
# ...      ...                                        ...
# 1993    1993                        Wingtech Technology
# 1995    1995  Shenzhen Feima International Supply Chain
# 1996    1997                                       NMDC
# 1997    1997                 Sichuan Changhong Electric
# 1998    1999                         Satellite Chemical
#
#                              Industry       Country   Sales   Profits  \
# 1                             Banking         China  208127   54028.3
# 2                Oil & Gas Operations  Saudi Arabia  400376  105363.0
# 4                             Banking         China  202069   46887.3
# ...

# %%
asia_assets=asia.sort_values(by=['Assets'],ascending=False)

# %%
asia_sales=asia.sort_values(by=['Sales'],ascending=False)

# %%
asia_profits=asia.sort_values(by=['Profits'],ascending=False)

# %%
asia_marketvalues=asia.sort_values(by=['Market_Value'],ascending=False)

# %%
australia=companies[companies['Country']== 'Australia']
australia
# Out:
#      Rank_nr                        Company                          Industry  \
# 74        75                      BHP Group                         Materials
# 106      107              Commonwealth Bank                           Banking
# 173      174          Westpac Banking Group                           Banking
# 191      192                            ANZ                           Banking
# 198      199  NAB - National Australia Bank                           Banking
# 311      312                Macquarie Group            Diversified Financials
# 371      371         Fortescue Metals Group                         Materials
# 374      374                     Woolworths                      Food Markets
# 546      547                            CSL             Drugs & Biotechnology
# 559      559                     Wesfarmers                      Food Markets
# 596      597                        Telstra       Telecommunications Services
# ...

# %%
australia_assets=australia.sort_values(by=['Assets'],ascending=False)

# %%
australia_sales=australia.sort_values(by=['Sales'],ascending=False)

# %%
australia_marketvalue=australia.sort_values(by=['Market_Value'],ascending=False)

# %%
australia_profits=australia.sort_values(by=['Profits'],ascending=False)

# %%
europe=companies[companies['Country'].isin(['Czech Republic','Belgiam','Denmark','Finland','France','Germany','Italy','Ireland','Netherlands','Poland','Portugal','Spain','Sweden','Switzerland','United Kingdom','Austria','Greece','Hungary','Norway','Luxenbourg'])]
europe
# Out:
#      Rank_nr                 Company                         Industry  \
# 15        16                   Shell             Oil & Gas Operations
# 24        25        Volkswagen Group                Consumer Durables
# 28        29                   Total             Oil & Gas Operations
# 34        35                 Allianz                        Insurance
# 37        38           HSBC Holdings                          Banking
# ...      ...                     ...                              ...
# 1965    1965                    VEON      Telecommunications Services
# 1978    1979  Logitech International  Technology Hardware & Equipment
# 1985    1986           Swedish Match            Food, Drink & Tobacco
# 1988    1989       EFG International                          Banking
# 1990    1991          Kloeckner & Co                        Materials
#
#              Country   Sales  Profits   Assets  Market_Value
# 15    United Kingdom  261761  20265.4   404379        211096
# ...

# %%
europe_assets=europe.sort_values(by=['Assets'],ascending=False)

# %%
europe_sales=europe.sort_values(by=['Sales'],ascending=False)

# %%
europe_profit=europe.sort_values(by=['Profits'],ascending=False)

# %%
europe_marketvalue=europe.sort_values(by=['Market_Value'],ascending=False)

# %%
south_america=companies[companies['Country'].isin(['Argentina','Brazil','Chile','Colombia','Peru','Uruguay'])]
south_america
# Out:
#      Rank_nr                  Company                Industry    Country  \
# 64        65                Petrobras    Oil & Gas Operations     Brazil
# 117      118                     Vale               Materials     Brazil
# 137      138    Itaú Unibanco Holding                 Banking     Brazil
# 181      182           Banco Bradesco                 Banking     Brazil
# 267      268          Banco do Brasil                 Banking     Brazil
# 295      296                Ecopetrol    Oil & Gas Operations   Colombia
# 400      401                      JBS   Food, Drink & Tobacco     Brazil
# 773      774        Banco Btg Pactual  Diversified Financials     Brazil
# 832      833                 Quinenco           Conglomerates      Chile
# 904      905               AntarChile  Diversified Financials      Chile
# 952      953                  Braskem               Chemicals     Brazil
# 961      962         Gerdau (Cosigua)               Materials     Brazil
# ...

# %%
southamerica_assets=south_america.sort_values(by=['Assets'],ascending=False)

# %%
southamerica_sales=south_america.sort_values(by=['Sales'],ascending=False)

# %%
southamerica_profit=south_america.sort_values(by=['Profits'],ascending=False)

# %%
southamerica_marketvalue=south_america.sort_values(by=['Market_Value'],ascending=False)

# %%
north_america=companies[companies['Country'].isin(['Bermuda','Mexico','Canada','United States','Cayman Islands'])]
north_america
# Out:
#      Rank_nr             Company                         Industry  \
# 0          1  Berkshire Hathaway           Diversified Financials
# 3          4      JPMorgan Chase           Diversified Financials
# 5          6              Amazon                        Retailing
# 6          7               Apple  Technology Hardware & Equipment
# 8          9     Bank of America                          Banking
# ...      ...                 ...                              ...
# 1986    1986              Twilio           IT Software & Services
# 1987    1986  Whitecap Resources             Oil & Gas Operations
# 1991    1992         Match Group           IT Software & Services
# 1992    1993                Onex           Diversified Financials
# 1999    2000     Sun Communities           Diversified Financials
#
#             Country   Sales   Profits   Assets  Market_Value
# 0     United States  276094   89795.0   958784        741476
# ...

# %%
northamerica_assets=north_america.sort_values(by=['Assets'],ascending=False)

# %%
northamerica_sales=north_america.sort_values(by=['Sales'],ascending=False)

# %%
northamerica_profit=north_america.sort_values(by=['Profits'],ascending=False)

# %%
northamerica_marketvalue=north_america.sort_values(by=['Market_Value'],ascending=False)

# %%
africa=companies[companies['Country'].isin(['Bahrain','Egypt','Morocco','Nigeria','South Africa'])]
africa
# Out:
#      Rank_nr                         Company                     Industry  \
# 446      447                         Naspers                        Media
# 447      448             Standard Bank Group                      Banking
# 471      472                       FirstRand       Diversified Financials
# 822      823                      Absa Group                      Banking
# 846      847                       MTN Group  Telecommunications Services
# 947      946                          Sanlam       Diversified Financials
# 972      973                           Sasol                    Chemicals
# 1070    1071              Sibanye Stillwater                    Materials
# 1147    1148        Impala Platinum Holdings                    Materials
# 1155    1156                      Old Mutual       Diversified Financials
# 1293    1293                         Nedbank                      Banking
# 1428    1429               Attijariwafa Bank                      Banking
# ...

# %%
africa_assets=africa.sort_values(by=['Assets'],ascending=False)

# %%
africa_sales=africa.sort_values(by=['Sales'],ascending=False)

# %%
africa_marketvalue=africa.sort_values(by=['Market_Value'],ascending=False)

# %%
africa_profits=africa.sort_values(by=['Profits'],ascending=False)

# %%
companies=companies.drop(736,axis=0)

# %%
companies.shape
# Out:
# (1999, 8)

# %%
top_sales=companies.sort_values(by=['Sales'],ascending=False)
top_sales
# Out:
#      Rank_nr                                    Company  \
# 22        23                                    Walmart
# 5          6                                     Amazon
# 2          3   Saudi Arabian Oil Company (Saudi Aramco)
# 44        45                                    Sinopec
# 20        21                                 PetroChina
# ...      ...                                        ...
# 1328    1329                                     Sofina
# 1439    1440                                     Rivian
# 1995    1995  Shenzhen Feima International Supply Chain
# 1783    1784                               Lucid Motors
# 1942    1943                                  Bradespar
#
#                           Industry        Country   Sales   Profits  Assets  \
# 22                       Retailing  United States  572754   13673.0  244860
# 5                        Retailing  United States  469822   33364.0  420549
# ...

# %%
top_assets=companies.sort_values(by=['Assets'],ascending=False)
top_assets
# Out:
#      Rank_nr                                    Company  \
# 1          2                                       ICBC
# 4          5                    China Construction Bank
# 7          8                 Agricultural Bank of China
# 337      338                                 Fannie Mae
# 12        13                              Bank of China
# ...      ...                                        ...
# 1904    1905                         China Aviation Oil
# 735     True             fred/companies/F2K/2022/105837
# 1942    1943                                  Bradespar
# 1745    1746                            Adani Total Gas
# 1995    1995  Shenzhen Feima International Supply Chain
#
#                           Industry        Country   Sales  Profits   Assets  \
# 1                          Banking          China  208127  54028.3  5518508
# 4                          Banking          China  202069  46887.3  4746951
# ...

# %%
top_profit=companies.sort_values(by=['Profits'],ascending=False)
top_profit
# Out:
#      Rank_nr                                   Company  \
# 2          3  Saudi Arabian Oil Company (Saudi Aramco)
# 6          7                                     Apple
# 0          1                        Berkshire Hathaway
# 10        11                                  Alphabet
# 11        12                                 Microsoft
# ...      ...                                       ...
# 1321    1322                               DiDi Global
# 1944    1945                   Hainan Airlines Holding
# 1219    1220                      Carnival Corporation
# 1093    1094                            Telecom Italia
# 1192    1193                       Kuaishou Technology
#
#                              Industry        Country   Sales   Profits  \
# 2                Oil & Gas Operations   Saudi Arabia  400376  105363.0
# 6     Technology Hardware & Equipment  United States  378697  100555.0
# 0              Diversified Financials  United States  276094   89795.0
# ...

# %%
top_marketvalue=companies.sort_values(by=['Market_Value'],ascending=False)
top_marketvalue
# Out:
#      Rank_nr                                   Company  \
# 6          7                                     Apple
# 2          3  Saudi Arabian Oil Company (Saudi Aramco)
# 11        12                                 Microsoft
# 10        11                                  Alphabet
# 5          6                                    Amazon
# ...      ...                                       ...
# 1244    1245                            Bank of Greece
# 1938    1939                           Hyakujushi Bank
# 1870    1871                       Basler Kantonalbank
# 1116    1117                                   Finatis
# 1379    1380                           X5 Retail Group
#
#                              Industry        Country   Sales   Profits  \
# 6     Technology Hardware & Equipment  United States  378697  100555.0
# 2                Oil & Gas Operations   Saudi Arabia  400376  105363.0
# 11             IT Software & Services  United States  184903   71185.0
# ...

# %%
sns.heatmap(companies.corr())
# Out:
# /var/folders/wz/5_bt4lmn20n0t2pnkvjfk6r40000gn/T/ipykernel_96340/3148094555.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(companies.corr())
# <Axes: >

# %%
sns.pairplot(companies)

# %%
sns.pairplot(companies,hue="Sales")

# %%
sns.pairplot(companies,hue="Profits")

# %%
sns.pairplot(companies,hue="Assets")

# %%
sns.pairplot(companies,hue="Market_Value")

# %%
industry=companies.groupby('Industry').mean()
industry
# Out:
# /var/folders/wz/5_bt4lmn20n0t2pnkvjfk6r40000gn/T/ipykernel_96340/3858722153.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   industry=companies.groupby('Industry').mean()
#                                          Sales      Profits         Assets  \
# Industry
# Aerospace & Defense               27293.222222  1772.272222   49956.055556
# Banking                           14089.106897  2758.488621  389453.300000
# Business Services & Supplies      12611.716049  1688.933333  122044.283951
# Capital Goods                     18056.203390  1325.759322   29158.491525
# Chemicals                         14358.093333  1646.169333   21026.946667
# Conglomerates                     23352.689655  2117.551724   51668.379310
# ...

# %%
sns.barplot(x = companies.Sales, y = companies.Industry)
# Out:
# <Axes: xlabel='Sales', ylabel='Industry'>

# %%
sns.barplot(x = companies.Profits, y = companies.Industry)
# Out:
# <Axes: xlabel='Profits', ylabel='Industry'>

# %%
sns.barplot(x = companies.Assets, y = companies.Industry)
# Out:
# <Axes: xlabel='Assets', ylabel='Industry'>

# %%
sns.barplot(x = companies.Market_Value, y = companies.Industry)
# Out:
# <Axes: xlabel='Market_Value', ylabel='Industry'>
